# %%
# !pip install selenium

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r'C:\Users\AYUSHI\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.flipkart.com")

# %%
Search=driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
Search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="818564682a7a90a6c4277fe260d04005", element="2e1df8e3-4d8b-4036-a6f4-8a7fe6b4375b")>

# %%
Search.send_keys('google pixel a4')

# %%
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="818564682a7a90a6c4277fe260d04005", element="b9fd9764-07c6-46d2-a044-a238df702377")>

# %%
search_btn.click()

# %%
Url=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    Url.append(i.get_attribute("href"))

# %%
len(Url)
# Out:
# 24

# %%
Url
# Out:
# ['https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=google+pixel+a4&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=465e9425-1996-431d-a71a-eca22366f363.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=pv9re6v1xs0000001643195593810&qH=4683fee28764aa75',
#  'https://www.flipkart.com/google-pixel-3a-clearly-white-64-gb/p/itmfgk4jfgstaack?pid=MOBFFGFPJSCEXMSG&lid=LSTMOBFFGFPJSCEXMSGODGRZE&marketplace=FLIPKART&q=google+pixel+a4&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=465e9425-1996-431d-a71a-eca22366f363.MOBFFGFPJSCEXMSG.SEARCH&ppt=hp&ppn=homepage&ssid=pv9re6v1xs0000001643195593810&qH=4683fee28764aa75',
# ...

# %%
Brand_Name=[]
Smartphone_name=[]
Colour=[]
RAM=[]
Storage_ROM=[]
Primary_Camera_and_Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price=[]
Product_URL=[]

# %%
for i in Url:
    driver.get(i)
    time.sleep(10)
   #fetching Brand_Name
    try:
        name=driver.find_element_by_xpath('//span[@class="B_NuCI"]')
        Brand_Name.append(name.text.replace("/n","new line"))
    except:
        Brand_Name.append('-')
    #fetching Smartphone_name
    try:
        name=driver.find_element_by_xpath('//table[@class="_14cfVK"]/tbody/tr[3]/td[2]/ul/li')
        Smartphone_name.append(name.text.replace("/n","new line"))
    except:
        Smartphone_name.append('-')
        #fetching Colour 
    try:
        name=driver.find_element_by_xpath('//table[@class="_14cfVK"]/tbody/tr[4]/td[2]/ul/li')
        Colour.append(name.text.replace("/n","new line"))
    except:
        Colour.append('-')
        #fetching RAM   
    try:
        name=driver.find_element_by_xpath('//div[@class="flxcaE"]/table/tbody/tr[2]/td[2]/ul/li')
        RAM.append(name.text.replace("/n","new line"))
    except:
        RAM.append('-')
        #fetching Storage(ROM)       
    try:
        name=driver.find_element_by_xpath('//li[@class="_21Ahn-"][1]')
        Storage_ROM.append(name.text.replace("/n","new line"))
    except:
        Storage_ROM.append('-')    
        #fetching Primary_Camera & Secondary_camera
    try:
        name=driver.find_element_by_xpath('//li[@class="_21Ahn-"][3]')
        Primary_Camera_and_Secondary_Camera.append(name.text.replace("/n","new line"))
    except:
        Primary_Camera_and_Secondary_Camera.append('-')  
        #fetching Display_Size
    try:
        name=driver.find_element_by_xpath('//div[@class="_2418kt"]/ul/li[2]')
        Display_Size.append(name.text.replace("/n","new line"))
    except:
        Display_Size.append('-')  
        #fetching Battery Capacity
    try:
        name=driver.find_element_by_xpath('//div[@class="_2418kt"]/ul/li[4]')
        Battery_Capacity.append(name.text.replace("/n","new line"))
    except:
        Battery_Capacity.append('-')
        #fetching Price
    try:
        name=driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(name.text.replace("/n","new line"))
    except:
        Price.append('-')  
        #fetching Product URL
    try:
        name=driver.find_element_by_xpath('//div[@class="_1fQZEK"]')
        Product_URL.append(name.text.replace("/n","new line"))
    except:
        Product_URL.append('-')

# %%
len(Brand_Name),len(Price),len(Smartphone_name),len(Colour),len(RAM),len(Storage_ROM),len(Primary_Camera_and_Secondary_Camera),len(Display_Size),len(Product_URL),len(Battery_Capacity)
# Out:
# (24, 24, 24, 24, 24, 24, 24, 24, 24, 24)

# %%
Product=pd.DataFrame()
Product['Brand name']= Brand_Name
Product['Price']= Price
Product['Smartphone_name']= Smartphone_name
Product['Colour']= Colour
Product['RAM|Storage_ROM']= Storage_ROM
Product['Primary_Camera|Secondary_Camera']= Primary_Camera_and_Secondary_Camera
Product['Display_Size']= Display_Size
Product['Battery_Capacity']= Battery_Capacity
Product['Product_URL']= Url
Product
# Out:
#                                            Brand name    Price  \
# 0    Google Pixel 4a (Just Black, 128 GB)  (6 GB RAM)  ₹27,999
# 1   Google Pixel 3a (Clearly White, 64 GB)  (4 GB ...  ₹39,999
# 2       Google Pixel (Quite Black, 32 GB)  (4 GB RAM)  ₹57,000
# 3       Google Pixel (Very Silver, 32 GB)  (4 GB RAM)  ₹57,000
# 4      Google Pixel (Quite Black, 128 GB)  (4 GB RAM)  ₹66,000
# 5      Google Pixel (Very Silver, 128 GB)  (4 GB RAM)  ₹41,000
# 6   Google Pixel XL (Very Silver, 128 GB)  (4 GB RAM)  ₹76,000
# 7   Google Pixel 2 (Clearly White, 128 GB)  (4 GB ...  ₹70,000
# 8    Google Pixel 3 XL (Not Pink, 128 GB)  (4 GB RAM)  ₹92,000
# 9      Google Pixel 2 (Kinda Blue, 64 GB)  (4 GB RAM)  ₹61,000
# 10     Google Pixel 2 (Just Black, 64 GB)  (4 GB RAM)  ₹61,000
# 11      Google Pixel 3 (Not Pink, 128 GB)  (4 GB RAM)  ₹80,000
# 12  Google Pixel 3a XL (Clearly White, 64 GB)  (4 ...  ₹44,999
# 13  Google Pixel 3 (Clearly White, 128 GB)  (4 GB ...  ₹80,000
# ...
